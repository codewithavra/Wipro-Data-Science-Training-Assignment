# %% [markdown]
# # Arithmatic operations

# %%
# addition
10+23
# Out:
# 33

# %%
# subtraction
20-12
# Out:
# 8

# %%
# multiplication
12*4
# Out:
# 48

# %%
# True division
16/5
# Out:
# 3.2

# %%
# Floor division
16//5
# Out:
# 3

# %%
# Modulus
16%5
# Out:
# 1

# %%
# exponent
2**3
# Out:
# 8

# %%
2**1500
# Out:
# ...

# %% [markdown]
# # Bitwise operation

# %%
# Bitwise AND
a=8
b=4
print(a & b)
# Out:
# 0

# %%
# Bitwise OR
a=8
b=4
print(a | b)
# Out:
# 12

# %%
# Bitwise XOR
a=8
b=4
print(a ^ b)
# Out:
# 12

# %%
# Bitwise NOT
a=1
print(~a)
# Out:
# -2

# %%
bin(10)
# Out:
# '0b1010'

# %% [markdown]
# # Comparison operations

# %%
# equal to
print(10==10)
# Out:
# True

# %%
# not equal
print(10!=10)
print(10!=20)
# Out:
# False
# True

# %%
# less than equal to
print(10<=10)
print(10<10)
# Out:
# True
# False

# %%
# greater than equal to
print(10>=10)
print(10>10)
# Out:
# True
# False

# %% [markdown]
# # Boolean operations

# %%
x=4
(x<6) and (x>2) # True and True => True
# Out:
# True

# %%
x=4
(x>10) or (x%2==0)  # False or True => True
# Out:
# True

# %% [markdown]
# # Identity and Membership operators

# %%
a=[1,2,3,4]
b=1

# check if b is present in a
b in a # to check b is a member of a or not
# Out:
# True

# %%
b is not a
# Out:
# True

# %%
a is b
# Out:
# False

# %%
b not in a
# Out:
# False

# %% [markdown]
# # Identity operator
# is
# is not
#
# # Membership operator
# in
# not in
