# %% [markdown]
# # Built in data structure

# %%
list [1,2,3,4]  # ordered collection 
tuple (1,2,3,4)  # Immutable ordered collection
set   {1,1,2,2,3,4}  # Unordered collection of unique value
dict (dictionary)
{'a':1, 'b':2, 'c':4}

# %% [markdown]
# # Sequences (list, tuple, string)

# %% [markdown]
# indexing

# %%
x='frog'
print(x[1])
# Out:
# r

# %%
x=(12,32,45,78)
print(x[2])
# Out:
# 45

# %% [markdown]
# Slicing

# %%
# slice out some portion using indexing
x='computer' # indexing--> 0 to 7, total=8
#  01234567

# %%
start=0
end=8
step=2
#print(x[start:end+1:step]) default step=1
print(x[start:end:step])
# Out:
# cmue

# %%
start=4
print(x[start:]) # end is missing, step is missing (default=1)
# Out:
# uter

# %%
end=8
print(x[:end])
# Out:
# computer

# %%
# -ve indexing
x='computer'
#      0   1   2   3   4   5   6   7 (+ve indexing)
#      c   o   m   p   u   t   e  r
#     -8  -7  -6  -5  -4  -3  -2  -1 (-ve indexing)
print(x[-5])
print(x[3])
# Out:
# p
# p

# %%
print(x[-3:-1])  # start=-3, end=-1
# Out:
# te

# %%
print(x[:-2])
# Out:
# comput

# %%
print(x[2:-4])
# Out:
# mp

# %%
print(x[2:-4:2])
# Out:
# m

# %%
x='computer'
print(x)
# Out:
# computer

# %%
a=[12,34,56,23,78]
b=a[2:5]

# %%
id(a)
# Out:
# 4587893376

# %%
id(b)
# Out:
# 4587861312

# %% [markdown]
# Adding/ Concatenating

# %%
x='abc'+'fgt'
print(x)
# Out:
# abcfgt

# %%
x=[1,2,3]+[4,5,6]
print(x)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(['x','y']+['a','b'])
# Out:
# ['x', 'y', 'a', 'b']

# %% [markdown]
# Multiplication

# %%
print('*'*30)
# Out:
# ******************************

# %%
print([1,2,3]*2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %% [markdown]
# Checking membership

# %%
x='bug'
print('u' in x)
print('y' in x)
# Out:
# True
# False

# %%
x=['pig', 'cow', 'horse']
print('cow' not in x)
# Out:
# False

# %% [markdown]
# iterating

# %%
x=[10,20,30,40,50]
for item in x:
    print(item) # iterating
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
#x=[4,1,7,3,9,5,6]
x=['pig', 'cow', 'horse']
for index,item in enumerate(x):
    print(index,item)
# Out:
# 0 pig
# 1 cow
# 2 horse

# %% [markdown]
# Number of items

# %%
x='bug'
print(len(x))
# Out:
# 3

# %%
x=['pig', 'cow', 'horse']
print(len(x))
# Out:
# 3

# %%
x=['pig', 'cow', 5,7]
print(len(x))
# Out:
# 4

# %% [markdown]
# To add the elements (sum)

# %%
x=[4,1,7,3,9,5,6]
print(sum(x))
# Out:
# 35

# %%
x=['pig', 'cow', '5','7']
print(sum(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 x=['pig', 'cow', '5','7']
# ----> 2 print(sum(x))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Sorting

# %%
x='bug'
print(sorted(x)) # Does not change the original list
print(x)
# Out:
# ['b', 'g', 'u']
# bug

# %%
x=['pig', 'cow', 'horse']
print(sorted(x))
# Out:
# ['cow', 'horse', 'pig']

# %% [markdown]
# Count

# %%
x='abcbbdefbg'
print(x.count('b'))
# Out:
# 4

# %% [markdown]
# Index

# %%
x=['pig', 'cow', 'horse']
print(x.index('cow'))
# Out:
# 1

# %%
x=['pig', 'cow', 'horse', 'cow']
print(x.index('cow'))
# Out:
# 1

# %% [markdown]
# Unpacking

# %%
zoo=['pig', 'cow', 'horse']
#a=pig; b=cow; c=horse
a,b,c=zoo
print(a,b,c)
# Out:
# pig cow horse

# %%
zoo=['pig', 'cow', 'horse']

for animals in zoo:
    print(animals)
# Out:
# pig
# cow
# horse

# %%
for player in 'argentina':
    print('messi')
# Out:
# messi
# messi
# messi
# messi
# messi
# messi
# messi
# messi
# messi

# %%
print(bool(True)) 
print(bool(False)) 
print(bool('True')) # True
print(bool('False')) # True
print(bool('')) #False
# Out:
# True
# False
# True
# True
# False
