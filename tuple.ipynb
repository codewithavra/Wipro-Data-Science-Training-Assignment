# %% [markdown]
# # Tuples

# %%
# It supports all operations for sequence
# Immutable, but member objects in it may be nutable

# %%
# constructor
x=()
x=(1,2,3,4,5)

# %%
type(x)
# Out:
# tuple

# %%
print(x)
# Out:
# (1, 2, 3, 4, 5)

# %%
a=1,2,3,4,5
print(a)
# Out:
# (1, 2, 3, 4, 5)

# %%
b=10,
print(b)
# Out:
# (10,)

# %%
lst=[1,2,3,4]
y=tuple(lst)

# %%
print(y)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# # Immutable, but member objects in it may be mutable

# %%
x=(12,23,34,56,78,54)

# %%
del(x[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 del(x[1])
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
x[3]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 x[3]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
x=(12,23,[1,2,3,4],34,56,78,54)
type(x)
# Out:
# tuple

# %%
x[2]
# Out:
# [1, 2, 30, 4]

# %%
x[2][2]=30

# %%
x
# Out:
# (12, 23, [1, 2, 30, 4], 34, 56, 78, 54)

# %%
del(x[2][1])

# %%
x
# Out:
# (12, 23, [1, 30, 4], 34, 56, 78, 54)

# %% [markdown]
# # Comparison between LIST and TUPLE

# %%
lst=[1,2,3]
lst.__sizeof__()
# Out:
# 72

# %%
tpl=(1,2,3)
tpl.__sizeof__()
# Out:
# 48

# %%
import timeit
t1=timeit.Timer('x=[1,2,3,4,5,6,7,8,9]')
t1.timeit()
# Out:
# 0.06242300000121759

# %%
t1=timeit.Timer('x=(1,2,3,4,5,6,7,8,9)')
t1.timeit()
# Out:
# 0.015073290998770972
