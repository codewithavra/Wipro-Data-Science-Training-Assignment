# %% [markdown]
# # Variables

# %%
# int variable
x=4

# %%
print(x)
# Out:
# 4

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
# string variable
x='hello'
print(type(x))
# Out:
# <class 'str'>

# %%
x=[10,20,30,40]
print(type(x))
# Out:
# <class 'list'>

# %%
y=x

# %%
x[3]=100

# %%
print(x)
# Out:
# [10, 20, 30, 100]

# %%
print(y)
# Out:
# [10, 20, 30, 100]

# %%
a=10
b=a

# %%
a=100

# %%
print(a) # 100
print(b) #10
# Out:
# 100
# 10

# %%
x=3.5
print(type(x))
# Out:
# <class 'float'>

# %% [markdown]
# class
#   attribute ---> real, imag
#   method -----> append(value)

# %%
L=[1,2,3]
print(L)
L.append(100)
print(L)
# Out:
# [1, 2, 3]
# [1, 2, 3, 100]

# %%
x=4.5+1.2j
print(x.real, '+', x.imag, 'i')
# Out:
# 4.5 + 1.2 i

# %% [markdown]
# x=100
#
# on x you may apply attribute or method
# x.real
# x.append(10)

# %%
x=4.5+1.2j
print(type(x))
# Out:
# <class 'complex'>

# %%
x=True
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>

# %%
a=['orange','apple', 'banana', 'mango']

for i in range(4):
    print(a[i])
# Out:
# orange
# apple
# banana
# mango

# %%
bucket=['orange','apple', 'banana', 'mango']

for fruits in range(4):
    print(bucket[fruits])
# Out:
# orange
# apple
# banana
# mango

# %%
bucket=['orange','apple', 'banana', 'mango']
for fruits in bucket:
    print(fruits)
# Out:
# orange
# apple
# banana
# mango
