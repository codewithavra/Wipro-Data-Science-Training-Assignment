# %% [markdown]
# # Exception handling

# %% [markdown]
# Explanation
#
# try: contains code that may cause an exception (error)
#
# except: handles the exception

# %%
try:
    num=int(input("Enter a number:"))
    print(10 / num)

except ValueError:
    print("Plesae enter a valid integer")

except ZeroDivisionError:
    print("Can not divide by zero")
# Out:
# Enter a number: 0
# Can not divide by zero

# %% [markdown]
# # try, except, else, finally

# %% [markdown]
# Explanation
#
# try:contains code that may cause an exception (error)
#
# except: handles the exception
#
# eles: executes if no exception occurs
#
# finally: Always executes, whether an exception occurs or not

# %%
try:
    num=int(input("Enter a number:"))
    result=100/num

except ValueError:
    print("Plesae enter a valid integer")

except ZeroDivisionError:
    print("Can not divide by zero")

else:
    print("Result:", result)

finally:
    print("Execution completed...")
# Out:
# Enter a number: 20
# Result: 5.0
# Execution completed...

# %% [markdown]
# # Catching multiple exception

# %%
try:
    num=int(input("Enter a number:"))
    print(100/num)

except(ValueError, ZeroDivisionError) as e:
    print("Error:",e)
# Out:
# Enter a number: 0
# Error: division by zero

# %% [markdown]
# # Catching any exception

# %%
try:
    num=int(input("Enter a number:"))
    print(100/num)

except Exception as e:
    print("An error occurred:",e)
# Out:
# Enter a number: 1.4
# An error occurred: invalid literal for int() with base 10: '1.4'
