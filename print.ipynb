# %%
print('Hello: %2d, value: %4f' % (12, 34.67))
# Out:
# Hello: 12, value: 34.670000

# %%
#I use <python> for <10> years
print('I use {} for {} years'.format('Python',10))
#<string>.format(var1,var2)
# Out:
# I use Python for 10 years

# %%
language='Python'
year=10
print(f'I use {language} for {year} years')
# Out:
# I use Python for 10 years

# %%
x=int(input('Enter a value:'))
# Out:
# Enter a value: 100

# %%
x
# Out:
# 100

# %%
type(x)
# Out:
# int

# %%
y=[x]

# %%
type(y)
# Out:
# list
